# %% [markdown]
# # Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data collection

# %%
df=pd.read_csv('Life Expectancy Data.csv')
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
# Cleaning columns
df.columns = df.columns.str.strip()

# %% [markdown]
# # Understanding data

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.nunique()
# Out:
# Country                             193
# Year                                 16
# Status                                2
# Life expectancy                     362
# Adult Mortality                     425
# infant deaths                       209
# Alcohol                            1076
# percentage expenditure             2328
# Hepatitis B                          87
# Measles                             958
# BMI                                 608
# under-five deaths                   252
# Polio                                73
# Total expenditure                   818
# Diphtheria                           81
# HIV/AIDS                            200
# GDP                                2490
# Population                         2278
# thinness  1-19 years                200
# thinness 5-9 years                  207
# Income composition of resources     625
# Schooling                           173
# dtype: int64

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 2563

# %% [markdown]
# # Stats info

# %%
df.describe()
# Out:
#               Year  Life expectancy  Adult Mortality  infant deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B        Measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df.describe(include=object)
# Out:
#             Country      Status
# count          2938        2938
# unique          193           2
# top     Afghanistan  Developing
# freq             16        2426

# %% [markdown]
# # Checking distribution

# %%
# Create subplots: 1 row, 3 columns
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

sns.histplot(df['Life expectancy'], kde=True, ax=axes[0], color='skyblue')
axes[0].set_title('Life expectancy')

sns.histplot(df['Total expenditure'], kde=True, ax=axes[1], color='lightgreen')
axes[1].set_title('Total expenditure')

sns.histplot(df['Schooling'], kde=True, ax=axes[2], color='salmon')
axes[2].set_title('Schooling')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check for outliers

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.boxplot(y=df['Hepatitis B'], ax=axes[0], color='skyblue')
axes[0].set_title('Hepatitis B')

sns.boxplot(y=df['Total expenditure'], ax=axes[1], color='lightgreen')
axes[1].set_title('Total Expenditure')

sns.boxplot(y=df['Schooling'], ax=axes[2], color='yellow')
axes[2].set_title('Schooling')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Handling Null Values

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df['Polio'] = df['Polio'].fillna(df['Polio'].median())

# %%
df['BMI'] = df['BMI'].fillna(df['BMI'].median())

# %%
df['Diphtheria'] = df['Diphtheria'].fillna(df['Diphtheria'].median())

# %% [markdown]
# # Using MICE imputation

# %%
from sklearn.experimental import enable_iterative_imputer 
from sklearn.impute import IterativeImputer

# %%
# Separate categorical and numerical columns
categorical_cols = ['Country','Status','Year']
numerical_cols = df.drop(columns=categorical_cols)

# %%
# Apply MICE (IterativeImputer) to numerical columns
imputer = IterativeImputer(random_state=0)
imputed_data = imputer.fit_transform(numerical_cols)

# %%
# Convert the result back to DataFrame
imputed_df = pd.DataFrame(imputed_data, columns=numerical_cols.columns)

# %%
# Combine categorical and imputed numerical data
df = pd.concat([df[categorical_cols].reset_index(drop=True), imputed_df], axis=1)

# %%
df.isnull().sum()
# Out:
# Country                            0
# Status                             0
# Year                               0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness  1-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# # Handling outlier

# %%
def replace_outlier(col):
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_bound= Q1-1.5*IQR
    upper_bound=Q3+1.5*IQR
    return lower_bound,upper_bound

# %%
replace_outlier(df['GDP'])
# Out:
# (-6126.492083527299, 11454.687039212165)

# %%
df_v=df.select_dtypes(include="number")
df_v.columns
# Out:
# Index(['Year', 'Life expectancy', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles', 'BMI',
#        'under-five deaths', 'Polio', 'Total expenditure', 'Diphtheria',
#        'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
for i in ['Life expectancy', 'Adult Mortality', 'infant deaths',
       'Alcohol', 'percentage expenditure', 'Hepatitis B', 'BMI',
       'under-five deaths', 'Polio', 'Total expenditure', 'Diphtheria',
       'HIV/AIDS', 'GDP', 'thinness  1-19 years', 'thinness 5-9 years',
       'Income composition of resources', 'Schooling']:
    lower_bound,upper_bound=replace_outlier(df[i])
    df[i]=np.where(df[i]<lower_bound,lower_bound,df[i])
    df[i]=np.where(df[i]>upper_bound,upper_bound,df[i])

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.boxplot(y=df['Hepatitis B'].dropna(), ax=axes[0], color='skyblue')
axes[0].set_title('Hepatitis B')

sns.boxplot(y=df['Total expenditure'].dropna(), ax=axes[1], color='lightgreen')
axes[1].set_title('Total Expenditure')

sns.boxplot(y=df['Schooling'].dropna(), ax=axes[2], color='yellow')
axes[2].set_title('Schooling')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Checking Correlation

# %%
df.select_dtypes(include='number').corr()
# Out:
#                                      Year  Life expectancy  Adult Mortality  \
# Year                             1.000000         0.169434        -0.067257
# Life expectancy                  0.169434         1.000000        -0.691350
# Adult Mortality                 -0.067257        -0.691350         1.000000
# infant deaths                   -0.047331        -0.565984         0.383925
# Alcohol                         -0.044790         0.418588        -0.218317
# percentage expenditure           0.032619         0.487002        -0.321553
# Hepatitis B                      0.201388         0.417028        -0.245928
# Measles                         -0.082493        -0.157955         0.032674
# BMI                              0.108484         0.555588        -0.390412
# under-five deaths               -0.052794        -0.602951         0.408091
# Polio                            0.111909         0.564260        -0.350437
# ...

# %%
# 1. Compute correlation matrix
corr_matrix = df.corr(numeric_only=True)

# 2. Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Hypothesis tesing

# %%
from scipy.stats import ttest_ind

# Group by Status
developed = df[df['Status'] == 'Developed']['Life expectancy']
developing = df[df['Status'] == 'Developing']['Life expectancy']

# t-test
t_stat, p_val = ttest_ind(developed, developing)

print('P-value:', p_val)

if p_val < 0.05:
    print("Reject Null Hypothesis: Status does not impact Life Expectancy.")
else:
    print("Fail to Reject Null Hypothesis: Status impacts Life Expectancy.")
# Out:
# P-value: 4.587158542511178e-171
# Reject Null Hypothesis: Status does not impact Life Expectancy.

# %%
from scipy.stats import f_oneway
groups = [group['Life expectancy'].dropna().values for name, group in df.groupby('Country')]

# Perform ANOVA
f_stat, p_val = f_oneway(*groups)

print('F-Statistic:', f_stat)
print('P-Value:', p_val)

# Decision based on p-value
if p_val < 0.05:
    print("Reject the Null Hypothesis: Country has a significant effect on Life Expectancy.")
else:
    print("Fail to Reject the Null Hypothesis: Country does not have a significant effect on Life Expectancy.")
# Out:
# F-Statistic: 182.00728460916363
# P-Value: 0.0
# Reject the Null Hypothesis: Country has a significant effect on Life Expectancy.

# %%
df = df.drop(['Status','Population','Measles', 'Year'], axis=1)

# %% [markdown]
# # Encoding

# %%
 df=pd.get_dummies(data=df, columns=['Country'],drop_first=True)

# %%
df.head(2)
# Out:
#    Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0             65.0            263.0           55.0     0.01
# 1             59.9            271.0           55.0     0.01
#
#    percentage expenditure  Hepatitis B   BMI  under-five deaths  Polio  \
# 0               71.279624         65.0  19.1               70.0   49.5
# 1               73.523582         62.0  18.6               70.0   58.0
#
#    Total expenditure  ...  Country_United Republic of Tanzania  \
# 0               8.16  ...                                False
# 1               8.18  ...                                False
#
#    Country_United States of America  Country_Uruguay  Country_Uzbekistan  \
# 0                             False            False               False
# 1                             False            False               False
#
#    Country_Vanuatu  Country_Venezuela (Bolivarian Republic of)  \
# 0            False                                       False
# ...

# %% [markdown]
# # X,Y Split

# %%
x = df.drop('Life expectancy', axis=1)
x.head(2)
# Out:
#    Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0            263.0           55.0     0.01               71.279624
# 1            271.0           55.0     0.01               73.523582
#
#    Hepatitis B   BMI  under-five deaths  Polio  Total expenditure  Diphtheria  \
# 0         65.0  19.1               70.0   49.5               8.16        65.0
# 1         62.0  18.6               70.0   58.0               8.18        62.0
#
#    ...  Country_United Republic of Tanzania  Country_United States of America  \
# 0  ...                                False                             False
# 1  ...                                False                             False
#
#    Country_Uruguay  Country_Uzbekistan  Country_Vanuatu  \
# 0            False               False            False
# 1            False               False            False
#
#    Country_Venezuela (Bolivarian Republic of)  Country_Viet Nam  \
# ...

# %%
y = df['Life expectancy']
y.head(2)
# Out:
# 0    65.0
# 1    59.9
# Name: Life expectancy, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train
# Out:
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 456             126.0            0.0     5.28              345.463714
# 462             152.0            0.0     3.81              150.743486
# 2172            143.0            0.0    10.43                0.000000
# 2667             13.0            3.0     1.29              594.645310
# 381              95.0            0.0     0.13              941.703687
# ...               ...            ...      ...                     ...
# 1638             59.0            0.0     6.91             1096.807347
# 1095            287.0            4.0     3.21               53.307827
# 1130            266.0           17.0     6.08               56.778587
# 1294             72.0            2.0     9.30             1096.807347
# 860              34.0            7.0     1.07                5.064689
#
#       Hepatitis B   BMI  under-five deaths  Polio  Total expenditure  \
# ...

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Check class distribution
print(df['Life expectancy'].value_counts())
# Out:
# Life expectancy
# 73.000000    45
# 75.000000    33
# 78.000000    31
# 73.600000    28
# 76.000000    25
#              ..
# 70.607565     1
# 49.500000     1
# 49.000000     1
# 55.100000     1
# 45.400000     1
# Name: count, Length: 362, dtype: int64

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train_Scaled=scaler.fit_transform(x_train)
x_train_Scaled
# Out:
# array([[-0.31694847, -0.7071253 ,  0.17926386, ..., -0.07164211,
#         -0.08014975, -0.07458342],
#        [-0.09193294, -0.7071253 , -0.19208057, ..., -0.07164211,
#         -0.08014975, -0.07458342],
#        [-0.16982293, -0.7071253 ,  1.48023246, ..., -0.07164211,
#         -0.08014975, -0.07458342],
#        ...,
#        [ 0.89467364,  0.19915476,  0.38135607, ..., -0.07164211,
#         -0.08014975, -0.07458342],
#        [-0.78428843, -0.60050412,  1.19477721, ..., -0.07164211,
#         -0.08014975, -0.07458342],
#        [-1.11315729, -0.33395116, -0.88424638, ..., -0.07164211,
#         -0.08014975, -0.07458342]])

# %%
x_test_Scaled=scaler.transform(x_test)
x_test_Scaled
# Out:
# array([[-0.3429118 , -0.28064057, -0.90950791, ..., -0.07164211,
#         -0.08014975, -0.07458342],
#        [-0.42945624, -0.7071253 ,  1.83389382, ..., -0.07164211,
#         -0.08014975, -0.07458342],
#        [-0.32560292, -0.7071253 ,  0.10347929, ..., -0.07164211,
#         -0.08014975, -0.07458342],
#        ...,
#        [ 0.86005587, -0.54719352, -0.64029853, ..., -0.07164211,
#         -0.08014975, -0.07458342],
#        [ 0.21962704, -0.7071253 ,  0.44956219, ..., -0.07164211,
#         -0.08014975, -0.07458342],
#        [-0.26502181, -0.65381471,  1.25540488, ..., -0.07164211,
#         -0.08014975, -0.07458342]])

# %% [markdown]
# #                                     Choose Model

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train_Scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test_Scaled)

# %%
from sklearn.linear_model import Ridge

model_ridge = Ridge(alpha=1)
model_ridge.fit(x_train_Scaled, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred_rg=model_ridge.predict(x_test_Scaled)

# %%
# testing accuracy
from sklearn.metrics import r2_score
print("Testing Accuracy is"),r2_score(y_pred_rg,y_test)*100
# Out:
# Testing Accuracy is
# (None, 94.53748233963563)

# %%
# testing accuracy
from sklearn.metrics import r2_score
print("Testing Accuracy is"),r2_score(y_pred,y_test)*100
# Out:
# Testing Accuracy is
# (None, 94.53195674549609)

# %%
#training accuracy
x_pred_train=model.predict(x_train_Scaled)
print("Training Accuracy is"),r2_score(x_pred_train,y_train)*100
# Out:
# Training Accuracy is
# (None, 95.07655951789421)

# %%
# Hyper parameter tunning
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

param_grid = {
    'alpha': [0.01, 0.1, 1, 10, 100]
}

ridge = Ridge()
grid = GridSearchCV(ridge, param_grid, cv=5, scoring='neg_mean_squared_error')
grid.fit(x_train_Scaled, y_train)

print("Best alpha:", grid.best_params_)
# Out:
# Best alpha: {'alpha': 1}

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = DecisionTreeRegressor(max_depth=10,min_samples_leaf=2,min_samples_split=10, random_state=42)
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, min_samples_leaf=2, min_samples_split=10,
#                       random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
#Testing accuracy
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# Mean Squared Error: 4.56
# R² Score: 0.95

# %%
#Hyper parameter tunning Decission tree
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

#Define the parameter grid
param_grid = {
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

#Initialize the base model
dt = DecisionTreeRegressor(random_state=42)

#Setup the grid search
grid_search = GridSearchCV(estimator=dt, param_grid=param_grid,
                           scoring='r2', cv=5, n_jobs=-1, verbose=1)

#Fit the model
grid_search.fit(x_train, y_train)

#Best parameters and score
print("Best Parameters:", grid_search.best_params_)
print("Best R² Score (CV):", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Best R² Score (CV): 0.9284352540965777

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint  # Import added

# Define model
rf = RandomForestRegressor()

# Corrected parameter grid
param_dist = {
    'n_estimators': randint(1, 500),
    'max_depth': randint(1, 30),
    'min_samples_split': randint(2, 10),
    'min_samples_leaf': randint(1, 10)
}

# Random search
random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=50,
    cv=5,
    n_jobs=-1,
    random_state=42
)

random_search.fit(x_train, y_train)
print("Best parameters:", random_search.best_params_)
# Out:
# Best parameters: {'max_depth': 21, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 314}

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score

# %%
rf_model= RandomForestRegressor(n_estimators=314,min_samples_leaf=1, max_features=5,min_samples_split=5, max_depth=21,random_state=42)

# %%
rf_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=21, max_features=5, min_samples_split=5,
#                       n_estimators=314, random_state=42)

# %%
accuracy = rf_model.score(x_test, y_test)
print(f"Model Accuracy:",accuracy *100)
# Out:
# Model Accuracy: 94.6374975685163

# %% [markdown]
# # Comparing all model accuracy

# %%
import matplotlib.pyplot as plt

models = ['Linear Regression', 'Decision Tree', 'Random Forest']
accuracies = [0.94, 0.95, 0.94]

plt.figure(figsize=(8, 6))
plt.bar(models, accuracies, color=['blue', 'green', 'red'])

# Adding labels and title
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Comparison')

plt.show()
